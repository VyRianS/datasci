# %%
# %matplotlib inline

import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
iris_data = pd.read_csv('/home/code/datasets/iris.data', na_values=['NA'])

# %%
iris_data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
sb.pairplot(iris_data.dropna(), hue='class')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6fd391aae6f5> in <module>
# ----> 1 sb.pairplot(iris_data.dropna(), hue='class')
#
# /usr/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# /usr/lib/python3.6/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ...

# %%
sb.pairplot(iris_data.dropna())

# %%
iris_data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
iris_data.loc[iris_data['class'] == 'versicolor', 'class'] = 'Iris-versicolor'

# %%
iris_data.loc[iris_data['class'] == 'Iris-setossa', 'class'] = 'Iris-setosa'

# %%
iris_data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_data = iris_data.loc[(iris_data['class'] != 'Iris-setosa') | (iris_data['sepal_width_cm'] >= 2.5)]

# %%
iris_data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       149.000000      149.000000       149.000000      144.000000
# mean          5.652309        3.059732         3.775168        1.243056
# std           1.313822        0.430104         1.758720        0.753607
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.400000        1.350000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
iris_data.loc[iris_data['class'] == 'Iris-setosa', 'sepal_width_cm'].hist()

# %%
iris_data.loc[(iris_data['class']=='Iris-versicolor') & (iris_data['sepal_length_cm']<=1)]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 77            0.067             3.0              5.0             1.7
# 78            0.060             2.9              4.5             1.5
# 79            0.057             2.6              3.5             1.0
# 80            0.055             2.4              3.8             1.1
# 81            0.055             2.4              3.7             1.0
#
#               class
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor

# %%
iris_data.loc[(iris_data['class']=='Iris-versicolor') & (iris_data['sepal_length_cm']<=1), 'sepal_length_cm'] *=100.0
iris_data.loc[iris_data['class'] == 'Iris-versicolor', 'sepal_length_cm'].hist()

# %%
iris_data.loc[(iris_data['sepal_length_cm'].isnull()) |
              (iris_data['sepal_width_cm'].isnull()) |
              (iris_data['petal_length_cm'].isnull()) |
              (iris_data['petal_width_cm'].isnull())]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
iris_data.loc[iris_data['class'] == 'Iris-setosa', 'petal_width_cm'].hist()

# %%
average_petal_width=iris_data.loc[iris_data['class']=='Iris-setosa','petal_width_cm'].mean()

iris_data.loc[(iris_data['class'] == 'Iris-setosa') &
              (iris_data['petal_width_cm'].isnull()),
              'petal_width_cm'] = average_petal_width

iris_data.loc[(iris_data['class'] == 'Iris-setosa') &
              (iris_data['petal_width_cm'] == average_petal_width)]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5            0.25
# 8               4.4             2.9              1.4            0.25
# 9               4.9             3.1              1.5            0.25
# 10              5.4             3.7              1.5            0.25
# 11              4.8             3.4              1.6            0.25
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
iris_data.loc[iris_data['class'] == 'Iris-setosa', 'petal_width_cm'].hist()

# %%
iris_data.loc[(iris_data['sepal_length_cm'].isnull()) |
              (iris_data['sepal_width_cm'].isnull()) |
              (iris_data['petal_length_cm'].isnull()) |
              (iris_data['petal_width_cm'].isnull())]
# Out:
# Empty DataFrame
# Columns: [sepal_length_cm, sepal_width_cm, petal_length_cm, petal_width_cm, class]
# Index: []

# %%
iris_data.to_csv('/home/code/datasets/iris-data-clean.csv', index=False)

# %%
iris_data_clean=pd.read_csv('/home/code/datasets/iris-data-clean.csv')

# %%
iris_data_clean.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
sb.pairplot(iris_data_clean, hue='class', diag_kind='hist')

# %%
assert 1==1

# %%
assert 1==2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-37-730332727407> in <module>
# ----> 1 assert 1==2
#
# AssertionError:

# %%
try:
    assert 1==2
except AssertionError:
    print('ERROR!')
# Out:
# ERROR!

# %%
assert len(iris_data_clean['class'].unique()) == 3

# %%
assert len(iris_data_clean['class'].unique()) == 4
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-40-eeb31c7e6276> in <module>
# ----> 1 assert len(iris_data_clean['class'].unique()) == 4
#
# AssertionError:

# %%
sb.pairplot(iris_data_clean)

# %%
# %watermark -a 'Jianyu Chen' -nmv --packages numpy,pandas,sklearn,matplotlib,seaborn
# Out:
# UsageError: Line magic function `%watermark` not found.

# %%
# %watermark -a 'Jianyu Chen' -nmv --packages numpy,pandas,sklearn,matplotlib,seaborn
# Out:
# UsageError: Line magic function `%watermark` not found.

# %%
# %load_ext watermark

# %%
# %watermark -a 'Jianyu Chen' -nmv --packages numpy,pandas,sklearn,matplotlib,seaborn
# Out:
# Jianyu Chen Wed Dec 19 2018
#
# CPython 3.6.5
# IPython 7.2.0
#
# numpy 1.15.4
# pandas 0.23.4
# sklearn 0.20.2
# matplotlib 3.0.2
# seaborn 0.9.0
#
# compiler   : GCC 4.8.5 20150623 (Red Hat 4.8.5-16)
# system     : Linux
# release    : 3.10.0-957.1.3.el7.x86_64
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 1
# interpreter: 64bit
